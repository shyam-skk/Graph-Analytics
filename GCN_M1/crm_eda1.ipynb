# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
#Loading Data set
crm_rawdata=pd.read_csv("crm.csv", sep=';')

# %%
#return the datatype of the varable or object
print(type(crm_rawdata))
print(crm_rawdata.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (448, 23)

# %%
#return first five rows
crm_rawdata.head()
# Out:
#      Product    Seller Authority Comp_size Competitors Purch_dept Partnership  \
# 0  Product A  Seller 6       Mid       Mid          No    Unknown          No
# 1  Product B  Seller 8       Mid       Big          No        Yes          No
# 2  Product F  Seller 1       Mid       Big          No         No         Yes
# 3  Product B  Seller 8       Mid       Big          No        Yes          No
# 4  Product C  Seller 1       Mid     Small     Unknown         No          No
#
#   Budgt_alloc Forml_tend  RFI  ...      Source   Client          Scope  \
# 0         Yes         No  Yes  ...    Referral  Current          Clear
# 1     Unknown         No   No  ...    Referral  Current          Clear
# 2          No         No   No  ...  Joint past  Current  Few questions
# 3          No         No   No  ...  Joint past  Current          Clear
# 4          No         No   No  ...     Unknown      New  Few questions
#
#           Strat_deal Cross_sale Up_sale    Deal_type       Needs_def  \
# 0     Very important         No     Yes      Project             Yes
# 1        Unimportant         No     Yes  Maintenance             Yes
# 2  Average important        Yes      No      Project  Info gathering
# 3     Very important         No     Yes  Maintenance             Yes
# 4  Average important         No      No      Project              No
#
#         Att_t_client Status
# 0  Strategic account    Won
# 1  Strategic account    Won
# 2  Strategic account    Won
# 3  Strategic account    Won
# 4             Normal    Won
#
# [5 rows x 23 columns]

# %%
#return last five rows
crm_rawdata.tail()
# Out:
#        Product    Seller Authority Comp_size Competitors Purch_dept  \
# 443  Product D  Seller 2       Low       Mid         Yes    Unknown
# 444  Product D  Seller 2       Mid       Mid         Yes    Unknown
# 445  Product D  Seller 2       Mid       Big         Yes    Unknown
# 446  Product D  Seller 2       Mid       Mid         Yes    Unknown
# 447  Product D  Seller 1       Low       Mid         Yes    Unknown
#
#     Partnership Budgt_alloc Forml_tend  RFI  ...       Source Client  Scope  \
# 443          No     Unknown         No  Yes  ...  Direct mail    New  Clear
# 444          No     Unknown         No  Yes  ...  Direct mail    New  Clear
# 445          No         Yes        Yes  Yes  ...  Direct mail    New  Clear
# 446          No     Unknown         No  Yes  ...  Direct mail    New  Clear
# 447          No     Unknown         No  Yes  ...     Referral    New  Clear
#
#             Strat_deal Cross_sale Up_sale Deal_type Needs_def Att_t_client  \
# 443  Average important         No      No  Solution       Yes   First deal
# 444  Average important         No      No  Solution       Yes   First deal
# 445  Average important         No      No  Solution       Yes   First deal
# 446  Average important         No      No  Solution       Yes   First deal
# 447  Average important         No      No  Solution       Yes   First deal
#
#     Status
# 443   Lost
# 444   Lost
# 445   Lost
# 446   Lost
# 447   Lost
#
# [5 rows x 23 columns]

# %%
crm_rawdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448 entries, 0 to 447
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product       448 non-null    object
#  1   Seller        448 non-null    object
#  2   Authority     448 non-null    object
#  3   Comp_size     448 non-null    object
#  4   Competitors   448 non-null    object
#  5   Purch_dept    448 non-null    object
#  6   Partnership   448 non-null    object
#  7   Budgt_alloc   448 non-null    object
#  8   Forml_tend    448 non-null    object
#  9   RFI           448 non-null    object
#  10  RFP           448 non-null    object
#  11  Growth        448 non-null    object
#  12  Posit_statm   448 non-null    object
#  13  Source        448 non-null    object
#  14  Client        448 non-null    object
#  15  Scope         448 non-null    object
#  16  Strat_deal    448 non-null    object
#  17  Cross_sale    448 non-null    object
#  18  Up_sale       448 non-null    object
#  19  Deal_type     448 non-null    object
#  20  Needs_def     448 non-null    object
#  21  Att_t_client  448 non-null    object
#  22  Status        448 non-null    object
# dtypes: object(23)
# memory usage: 80.6+ KB

# %%
# print column names and its data types
#print(crm_rawdata.dtypes)
#list(crm_rawdata.columns)
#crm_rawdata.columns.values.tolist()

# %%
# checking for null values.
#crm_rawdata.isnull()
#crm_rawdata.isnull().sum()

# %%
print(crm_rawdata.isnull().values.any())
print(crm_rawdata.isnull().sum().sum())
# Out:
# False
# 0

# %%
#crm_rawdata.describe()

# %%
crm_rawdata.iloc[:, :13].describe()
# Out:
#           Product    Seller Authority Comp_size Competitors Purch_dept  \
# count         448       448       448       448         448        448
# unique         14        18         3         3           3          3
# top     Product D  Seller 1       Mid       Big          No         No
# freq          141       178       399       264         285        302
#
#        Partnership Budgt_alloc Forml_tend  RFI  RFP  Growth Posit_statm
# count          448         448        448  448  448     448         448
# unique           2           3          2    2    2       4           3
# top             No         Yes         No  Yes  Yes  Stable     Neutral
# freq           395         219        396  239  402     403         343

# %%
crm_rawdata.iloc[:, 12:].describe()
# Out:
#        Posit_statm      Source   Client  Scope         Strat_deal Cross_sale  \
# count          448         448      448    448                448        448
# unique           3           8        3      3                  3          2
# top        Neutral  Joint past  Current  Clear  Average important         No
# freq           343         339      286    411                296        400
#
#        Up_sale Deal_type Needs_def Att_t_client Status
# count      448       448       448          448    448
# unique       2         4         4            4      2
# top        Yes   Project       Yes       Normal    Won
# freq       241       279       420          237    227

# %%
#crm_rawdata.to_excel(r'CRM_new.xlsx', index = False)

# %%
ax = sns.countplot(y="Status", data=crm_rawdata)
fig = plot.gcf()
fig.set_size_inches(4, 2)

# %%
g = sns.catplot(y="Product", hue="Status",
                data=crm_rawdata, kind="count",
                height=7, aspect=.9);

# %%
g = sns.catplot(y="Seller", hue="Status",
                data=crm_rawdata, kind="count",
                height=7, aspect=.9);

# %%
g = sns.catplot(x="Competitors", hue="Status",
                data=crm_rawdata, kind="count",
                height=4, aspect=1);

# %%
g = sns.catplot(x="Up_sale", hue="Status",
                data=crm_rawdata, kind="count",
                height=4, aspect=.7);

# %%
g = sns.catplot(x="Client", hue="Status",
                data=crm_rawdata, kind="count",
                height=4, aspect=1);

# %%
g = sns.catplot(x="Comp_size", hue="Status",
                data=crm_rawdata, kind="count",
                height=4, aspect=1);

# %%
g = sns.catplot(x="Source", hue="Status",
                data=crm_rawdata, kind="count",
                height=6, aspect=1.5);

# %%
g = sns.catplot(x="Comp_size", hue="Product", col="Status",
                data=crm_rawdata, kind="count",
                height=6, aspect=.8);

# %%
def categorical_summarized(dataframe, x=None, y=None, hue=None, palette='Set1', verbose=True):
    '''
    Helper function that gives a quick summary of a given column of categorical data
    Arguments
    =========
    dataframe: pandas dataframe
    x: str. horizontal axis to plot the labels of categorical data, y would be the count
    y: str. vertical axis to plot the labels of categorical data, x would be the count
    hue: str. if you want to compare it another variable (usually the target variable)
    palette: array-like. Colour of the plot
    Returns
    =======
    Quick Stats of the data and also the count plot
    '''
    if x == None:
        column_interested = y
    else:
        column_interested = x
    series = dataframe[column_interested]
    print(series.describe())
    print('mode: ', series.mode())
    if verbose:
        print('='*80)
        print(series.value_counts())

    sns.countplot(x=x, y=y, hue=hue, data=dataframe, palette=palette)
    fig = plot.gcf()
    fig.set_size_inches(6, 3)
    plot.show()

# %%
# Target Variable: Survival
c_palette = ['tab:blue', 'tab:orange']
categorical_summarized(crm_rawdata, y = 'Status', palette=c_palette)
# Out:
# count     448
# unique      2
# top       Won
# freq      227
# Name: Status, dtype: object
# mode:  0    Won
# dtype: object
# ================================================================================
# Won     227
# Lost    221
# Name: Status, dtype: int64

# %%
# Feature Variable: Gender
categorical_summarized(crm_rawdata, y = 'Product', hue='Status', palette=c_palette)
# Out:
# count           448
# unique           14
# top       Product D
# freq            141
# Name: Product, dtype: object
# mode:  0    Product D
# dtype: object
# ================================================================================
# Product D    141
# Product B    122
# Product A     67
# Product C     36
# Product F     22
# Product H     22
# Product E     12
# Product N      8
# Product I      7
# Product J      4
# Product G      3
# Product K      2
# Product L      1
# Product P      1
# Name: Product, dtype: int64

# %%
# Feature Variable: Gender
categorical_summarized(crm_rawdata, y = 'Seller', hue='Status', palette=c_palette)
# Out:
# count          448
# unique          18
# top       Seller 1
# freq           178
# Name: Seller, dtype: object
# mode:  0    Seller 1
# dtype: object
# ================================================================================
# Seller 1     178
# Seller 9     126
# Seller 2      65
# Seller 3      17
# Seller 4      13
# Seller 10     11
# Seller 14      9
# Seller 8       9
# Seller 11      4
# Seller 6       4
# Seller 7       3
# Seller 5       2
# Seller 12      2
# Seller 13      1
# Seller 20      1
# Seller 16      1
# Seller 17      1
# Seller 15      1
# Name: Seller, dtype: int64

# %%
#crm_col_names = crm_rawdata.columns.get_values()
categorical = crm_rawdata.columns.values.tolist()

# %%
fig, ax = plt.subplots(6, 4, figsize=(20, 50))
for variable, subplot in zip(categorical, ax.flatten()):
    sns.countplot(crm_rawdata[variable], ax=subplot)
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %%
# Feature Variable: Gender
categorical_summarized(crm_rawdata, y = 'Comp_size', hue='Status', palette=c_palette)
# Out:
# count     448
# unique      3
# top       Big
# freq      264
# Name: Comp_size, dtype: object
# mode:  0    Big
# dtype: object
# ================================================================================
# Big      264
# Mid      136
# Small     48
# Name: Comp_size, dtype: int64
